# %%
#Je reviens à quelque chose de beaucoup plus simple. On va prouver que l'on obtient le bon FF pour STF classique. 
#Travaillons en mode dense, facile.
# This first version is for the classical STF. 
# Now, try to get to the domain-based STF...

import bempp.api 
import numpy as np
import mtf
from mtf.preconditioning.osrc import osrc_MtE
from mtf.utils.iterative import gmres

from bempp.api.operators.boundary.sparse import identity

from bempp.api.assembly.blocked_operator import BlockedOperator
from mtf.assembly.operators import GeneralizedBlockedOperator
from bempp.api import ZeroBoundaryOperator

from mtf.utils import bhmie
from mtf.config import config
from mtf.functions import define_bempp_functions
from matplotlib import pyplot as plt
from decimal import Decimal

bempp.api.enable_console_logging()

M = 3

mtf.config.set_case("B")

tangential_trace, neumann_trace = define_bempp_functions(config)

k0, k1 = config["k_ext"], config["k_int"]
lambda_par, freq = config["lambda"], config["frequency"]

polarization = config["polarization"]
direction = config["direction"]

eps_rel = config["eps_rel"]
mu_rel = config["mu_rel"]
mu0 = config["mu_ext"]
mu1 = mu_rel * mu0

eta_rel = np.sqrt(mu_rel / eps_rel)

print("The exterior wavenumber is: {0}".format(k0))
print("The interior wavenumber is: {0}".format(k1))

print("----")
print("The exterior wavelenght is: {0}".format(lambda_par))
print("The exterior frequency is: {:.2E}".format(Decimal(freq)))

# To do: Go to the multi-domain STF...
#segments = [[10], [10]]
#swapped_normals = [[10], []]

segments = [[10, 20], [10, 12], [12,20]]
swapped_normals = [[10, 20], [], [12]]

k_int, k_ext = config["k_int"], config["k_ext"]

n = k_int / k_ext
refIndex = n
numAngles = 901
s1, s2, qext, qsca, qback, gsca = bhmie(k_ext, k_int / k_ext, numAngles)
angles = config['angles']

k_list = [k0]
eta_rel_list = [1]
mu_list = [mu0]

for index in range(M-1):
  k_list.append(k1)
  mu_list.append(mu1)
  eta_rel_list.append(eta_rel)


precision = 10

h = 2 * np.pi/(precision*k0)
grid = bempp.api.shapes.multitrace_sphere(h=h)

print(h, ': h')
print(precision, ': precision')
print(grid.number_of_edges * 2, ': N')


dA = [bempp.api.function_space(grid, "RWG", 0, segments=seg, swapped_normals=normals,
                                      include_boundary_dofs=True)
              for seg, normals in zip(segments, swapped_normals)]

p1dA = [bempp.api.function_space(grid, "DP", 1, segments=seg, swapped_normals=normals,
                                      include_boundary_dofs=True)
              for seg, normals in zip(segments, swapped_normals)]

rA = [bempp.api.function_space(grid, "RWG", 0, segments=seg, swapped_normals=normals,
                                      include_boundary_dofs=True)
              for seg, normals in zip(segments, swapped_normals)]
tA = [bempp.api.function_space(grid, "SNC", 0, segments=seg, swapped_normals=normals,
                                      include_boundary_dofs=True)
              for seg, normals in zip(segments, swapped_normals)]

multitrace_ops = []
osrc_ops = []
# > Assemble all diagonal operators
for index in range(M):
  k = k_list[index]
  mu = mu_list[index]
  eta = eta_rel_list[index]
  efie = bempp.api.operators.boundary.maxwell.electric_field(dA[index], rA[index], tA[index], k)
  mfie = bempp.api.operators.boundary.maxwell.magnetic_field(dA[index], rA[index], tA[index], k)
  osrc = osrc_MtE(dA[index], rA[index], tA[index], p1dA[index], k)
  zero = (1+1j) * bempp.api.ZeroBoundaryOperator(dA[index], rA[index], tA[index])
  multitrace_ops.append(GeneralizedBlockedOperator([[mfie, eta * efie],[- 1/eta * efie, mfie]]))
  osrc_ops.append(GeneralizedBlockedOperator([[zero, eta * osrc],[- 1/eta * osrc, zero]]))
    
# Define the final operator
block_system = [M * [None] for _ in range(M)]

for i in range(M):
  for j in range(M):
    if i == j:
      block_system[i][j] = 2 * multitrace_ops[i]
    else:
      all = segments[i] + segments[j]
      non_disjoint = np.unique(all).shape[0] != len(all)
      
      if non_disjoint:
        ident = identity(dA[j], rA[i], tA[i])
        op = BlockedOperator(2, 2)
        #op[0, 0] = -ident
        op[0, 0] = ident
        op[1, 1] = ident
        op.weak_form()
        #op[1, 1] = ident
        block_system[i][j] = op
      else:
        op = BlockedOperator(2, 2)
        zero = ZeroBoundaryOperator(dA[j], rA[i], tA[i])
        op[0, 0] = zero
        op[1, 1] = zero
        block_system[i][j] = op

# Define the final operator
block_osrc = [M * [None] for _ in range(M)]

for i in range(M):
  for j in range(M):
    if i == j:
      block_osrc[i][j] = 2 * osrc_ops[i]
    else:
      all = segments[i] + segments[j]
      non_disjoint = np.unique(all).shape[0] != len(all)
      
      if non_disjoint:
        ident = identity(dA[j], rA[i], tA[i])
        op = BlockedOperator(2, 2)
        #op[0, 0] = -ident
        op[0, 0] = ident
        op[1, 1] = ident
        op.weak_form()
        #op[1, 1] = ident
        block_osrc[i][j] = op
      else:
        op = BlockedOperator(2, 2)
        zero = ZeroBoundaryOperator(dA[j], rA[i], tA[i])
        op[0, 0] = zero
        op[1, 1] = zero
        block_osrc[i][j] = op

block_osrc2 = [M * [None] for _ in range(M)]
for i in range(M):
  for j in range(M):
    if i == j:
      block_osrc2[i][j] = 2 * osrc_ops[i]
    else:
      op = BlockedOperator(2, 2)
      zero = ZeroBoundaryOperator(dA[j], rA[i], tA[i])
      op[0, 0] = zero
      op[1, 1] = zero
      block_osrc2[i][j] = op

lhs_op = GeneralizedBlockedOperator(block_system)
op_wf = lhs_op.weak_form()

P_op = GeneralizedBlockedOperator(block_osrc2)
P_wf = P_op.weak_form()

rhs = [2 * bempp.api.GridFunction(rA[0], dual_space = tA[0], fun=tangential_trace),
      2 * bempp.api.GridFunction(rA[0], dual_space = tA[0], fun=neumann_trace)]

for i in range(1, M):
    zero_func = [bempp.api.GridFunction.from_zeros(dA[i]),bempp.api.GridFunction.from_zeros(dA[i])]
    rhs = rhs + zero_func


b = bempp.api.assembly.blocked_operator.projections_from_grid_functions_list(rhs, lhs_op.dual_to_range_spaces)
N = b.shape[0]
A = bempp.api.as_matrix(op_wf)
x = np.linalg.solve(A, b)

x_gmres, conv_gmres, res_gmres = gmres(P_wf * op_wf, P_wf * b, return_residuals=True, restart = 1000)
#x_gmres, conv_gmres, res_gmres = gmres(op_wf, b, return_residuals=True, restart = 1000, maxiter=1000)

sol = bempp.api.assembly.blocked_operator.grid_function_list_from_coefficients(x.ravel(), lhs_op.domain_spaces)
sol_gmres = bempp.api.assembly.blocked_operator.grid_function_list_from_coefficients(x_gmres.ravel(), lhs_op.domain_spaces)

far_field_points = config['far_field_points']
electric_far = bempp.api.operators.far_field.maxwell.electric_field(sol[1].space, far_field_points, k0)
magnetic_far = bempp.api.operators.far_field.maxwell.magnetic_field(sol[0].space, far_field_points, k0)    

far_field =  electric_far * sol[1] + magnetic_far * sol[0]

far_field_gmres =  electric_far * sol_gmres[1] + magnetic_far * sol_gmres[0]

A22 = far_field[2,:]
A22_gmres = far_field_gmres[2,:]
uh = 10 * np.log10(4 * np.pi * np.abs(A22[:1801]))
uh_gmres = 10 * np.log10(4 * np.pi * np.abs(A22_gmres[:1801]))
u =  10 * np.log10(4 * np.pi * np.abs(s1 / (-1j * k_ext) ))
rel_error = np.linalg.norm(uh - u) / np.linalg.norm(u)
rel_error_gmres = np.linalg.norm(uh_gmres - u) / np.linalg.norm(u)

print(rel_error, 'REL')
print(rel_error_gmres, 'REL_GMRES')
# Out:
# bempp:HOST:INFO: Created grid with id c0553820-47cc-45da-8b89-33246e7dd123. Elements: 792. Edges: 1174. Vertices: 385
# bempp:HOST:WARNING: Setting include_boundary_dofs has no effect on this space type.
# bempp:HOST:WARNING: Setting include_boundary_dofs has no effect on this space type.
# bempp:HOST:WARNING: Setting include_boundary_dofs has no effect on this space type.
# The exterior wavenumber is: 5.0
# The interior wavenumber is: 6.892024376045111
# ----
# The exterior wavelenght is: 1.2566370614359172
# The exterior frequency is: 2.39E+8
#
# 0.25132741228718347 : h
# 5 : precision
# 2348 : N
# /usr/local/lib/python3.10/dist-packages/bempp/api/assembly/discrete_boundary_operator.py:639: SparseEfficiencyWarning: splu converted its input to CSC format
#   solver = solver_interface(actual_mat)
# /usr/local/lib/python3.10/dist-packages/pyopencl/cache.py:495: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   _create_built_program_from_source_cached(
# /usr/local/lib/python3.10/dist-packages/pyopencl/cache.py:499: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   prg.build(options_bytes, devices)
# 1 0 NON DISJOINT
# 2 0 NON DISJOINT
# 0 1 NON DISJOINT
# 2 1 NON DISJOINT
# 0 2 NON DISJOINT
# 1 2 NON DISJOINT
# bempp:HOST:INFO: Starting GMRES iteration
# bempp:HOST:INFO: GMRES Iteration 1 with residual 0.6408288056678475
# bempp:HOST:INFO: GMRES Iteration 2 with residual 0.4895168312750949
# bempp:HOST:INFO: GMRES Iteration 3 with residual 0.3917482413092171
# bempp:HOST:INFO: GMRES Iteration 4 with residual 0.350649353518132
# bempp:HOST:INFO: GMRES Iteration 5 with residual 0.31191923803296034
# bempp:HOST:INFO: GMRES Iteration 6 with residual 0.2825333805457382
# bempp:HOST:INFO: GMRES Iteration 7 with residual 0.2621474376326288
# bempp:HOST:INFO: GMRES Iteration 8 with residual 0.245629456942821
# bempp:HOST:INFO: GMRES Iteration 9 with residual 0.22313939807964175
# bempp:HOST:INFO: GMRES Iteration 10 with residual 0.2146571390603045
# bempp:HOST:INFO: GMRES Iteration 11 with residual 0.202927972326715
# bempp:HOST:INFO: GMRES Iteration 12 with residual 0.1915723243728163
# bempp:HOST:INFO: GMRES Iteration 13 with residual 0.17985845910338555
# bempp:HOST:INFO: GMRES Iteration 14 with residual 0.17028919551516192
# bempp:HOST:INFO: GMRES Iteration 15 with residual 0.16278866393503336
# bempp:HOST:INFO: GMRES Iteration 16 with residual 0.15657767302476716
# bempp:HOST:INFO: GMRES Iteration 17 with residual 0.14780067688505735
# bempp:HOST:INFO: GMRES Iteration 18 with residual 0.14360052518813105
# bempp:HOST:INFO: GMRES Iteration 19 with residual 0.13578050021890084
# bempp:HOST:INFO: GMRES Iteration 20 with residual 0.13041950148689352
# bempp:HOST:INFO: GMRES Iteration 21 with residual 0.12545773929657839
# bempp:HOST:INFO: GMRES Iteration 22 with residual 0.12050973389473225
# bempp:HOST:INFO: GMRES Iteration 23 with residual 0.11464189403782549
# bempp:HOST:INFO: GMRES Iteration 24 with residual 0.11074526279555258
# bempp:HOST:INFO: GMRES Iteration 25 with residual 0.10671352726994487
# bempp:HOST:INFO: GMRES Iteration 26 with residual 0.10286918455451749
# bempp:HOST:INFO: GMRES Iteration 27 with residual 0.09966339905106357
# bempp:HOST:INFO: GMRES Iteration 28 with residual 0.09626483068357555
# bempp:HOST:INFO: GMRES Iteration 29 with residual 0.09215666918235116
# bempp:HOST:INFO: GMRES Iteration 30 with residual 0.0892548918716722
# bempp:HOST:INFO: GMRES Iteration 31 with residual 0.08667253574548403
# bempp:HOST:INFO: GMRES Iteration 32 with residual 0.08349383363888861
# bempp:HOST:INFO: GMRES Iteration 33 with residual 0.08044690205389554
# bempp:HOST:INFO: GMRES Iteration 34 with residual 0.07787451784805928
# bempp:HOST:INFO: GMRES Iteration 35 with residual 0.07534293920066937
# bempp:HOST:INFO: GMRES Iteration 36 with residual 0.07255761654442455
# bempp:HOST:INFO: GMRES Iteration 37 with residual 0.07055944556000601
# bempp:HOST:INFO: GMRES Iteration 38 with residual 0.06802871202086253
# bempp:HOST:INFO: GMRES Iteration 39 with residual 0.06559509625525173
# bempp:HOST:INFO: GMRES Iteration 40 with residual 0.06410245059386371
# bempp:HOST:INFO: GMRES Iteration 41 with residual 0.0618132085358714
# bempp:HOST:INFO: GMRES Iteration 42 with residual 0.06013562962433979
# bempp:HOST:INFO: GMRES Iteration 43 with residual 0.05805730382479056
# bempp:HOST:INFO: GMRES Iteration 44 with residual 0.05655499748249949
# bempp:HOST:INFO: GMRES Iteration 45 with residual 0.054678704206127894
# bempp:HOST:INFO: GMRES Iteration 46 with residual 0.05320506383887622
# bempp:HOST:INFO: GMRES Iteration 47 with residual 0.05124599384207724
# bempp:HOST:INFO: GMRES Iteration 48 with residual 0.04941092424123648
# bempp:HOST:INFO: GMRES Iteration 49 with residual 0.04801977541540677
# bempp:HOST:INFO: GMRES Iteration 50 with residual 0.04652457130025116
# bempp:HOST:INFO: GMRES Iteration 51 with residual 0.04549788765309443
# bempp:HOST:INFO: GMRES Iteration 52 with residual 0.04406790784964919
# bempp:HOST:INFO: GMRES Iteration 53 with residual 0.04276288455457387
# bempp:HOST:INFO: GMRES Iteration 54 with residual 0.041442292067128156
# bempp:HOST:INFO: GMRES Iteration 55 with residual 0.0402542856331392
# bempp:HOST:INFO: GMRES Iteration 56 with residual 0.039206655346970855
# bempp:HOST:INFO: GMRES Iteration 57 with residual 0.03800368444472203
# bempp:HOST:INFO: GMRES Iteration 58 with residual 0.03669802806663056
# bempp:HOST:INFO: GMRES Iteration 59 with residual 0.03573937741145391
# bempp:HOST:INFO: GMRES Iteration 60 with residual 0.03486385724996486
# bempp:HOST:INFO: GMRES Iteration 61 with residual 0.03383786615798555
# bempp:HOST:INFO: GMRES Iteration 62 with residual 0.032859318730813325
# bempp:HOST:INFO: GMRES Iteration 63 with residual 0.03188728376997842
# bempp:HOST:INFO: GMRES Iteration 64 with residual 0.0311212889675515
# bempp:HOST:INFO: GMRES Iteration 65 with residual 0.030145538536326656
# bempp:HOST:INFO: GMRES Iteration 66 with residual 0.029360011204864825
# bempp:HOST:INFO: GMRES Iteration 67 with residual 0.028510065471844648
# bempp:HOST:INFO: GMRES Iteration 68 with residual 0.027699914507570755
# bempp:HOST:INFO: GMRES Iteration 69 with residual 0.02703968057977577
# bempp:HOST:INFO: GMRES Iteration 70 with residual 0.026299033339927384
# bempp:HOST:INFO: GMRES Iteration 71 with residual 0.025691261899098435
# bempp:HOST:INFO: GMRES Iteration 72 with residual 0.024884450802481417
# bempp:HOST:INFO: GMRES Iteration 73 with residual 0.024316752568620207
# bempp:HOST:INFO: GMRES Iteration 74 with residual 0.02364426648165622
# bempp:HOST:INFO: GMRES Iteration 75 with residual 0.02303304284016576
# bempp:HOST:INFO: GMRES Iteration 76 with residual 0.02240779389288452
# bempp:HOST:INFO: GMRES Iteration 77 with residual 0.02192085751061647
# bempp:HOST:INFO: GMRES Iteration 78 with residual 0.0214593779631638
# bempp:HOST:INFO: GMRES Iteration 79 with residual 0.02075980182625055
# bempp:HOST:INFO: GMRES Iteration 80 with residual 0.020239687464144906
# bempp:HOST:INFO: GMRES Iteration 81 with residual 0.019547830125151426
# bempp:HOST:INFO: GMRES Iteration 82 with residual 0.019078451385714536
# bempp:HOST:INFO: GMRES Iteration 83 with residual 0.0185831279787551
# bempp:HOST:INFO: GMRES Iteration 84 with residual 0.01812757055047012
# bempp:HOST:INFO: GMRES Iteration 85 with residual 0.017623770950765165
# bempp:HOST:INFO: GMRES Iteration 86 with residual 0.017275293077227746
# bempp:HOST:INFO: GMRES Iteration 87 with residual 0.016748441522497062
# bempp:HOST:INFO: GMRES Iteration 88 with residual 0.01632337873598494
# bempp:HOST:INFO: GMRES Iteration 89 with residual 0.015929076549083192
# bempp:HOST:INFO: GMRES Iteration 90 with residual 0.015480811969286322
# bempp:HOST:INFO: GMRES Iteration 91 with residual 0.01517219766148743
# bempp:HOST:INFO: GMRES Iteration 92 with residual 0.014783665715898573
# bempp:HOST:INFO: GMRES Iteration 93 with residual 0.01444717136171929
# bempp:HOST:INFO: GMRES Iteration 94 with residual 0.014135251926305877
# bempp:HOST:INFO: GMRES Iteration 95 with residual 0.013757332439743716
# bempp:HOST:INFO: GMRES Iteration 96 with residual 0.013445515094373585
# bempp:HOST:INFO: GMRES Iteration 97 with residual 0.013087704175675037
# bempp:HOST:INFO: GMRES Iteration 98 with residual 0.012728619124855213
# bempp:HOST:INFO: GMRES Iteration 99 with residual 0.012461545725182384
# bempp:HOST:INFO: GMRES Iteration 100 with residual 0.01213304333895252
# bempp:HOST:INFO: GMRES Iteration 101 with residual 0.0118847827031537
# bempp:HOST:INFO: GMRES Iteration 102 with residual 0.011559715389489272
# bempp:HOST:INFO: GMRES Iteration 103 with residual 0.011322870786947294
# bempp:HOST:INFO: GMRES Iteration 104 with residual 0.011075469780788952
# bempp:HOST:INFO: GMRES Iteration 105 with residual 0.010781695049676092
# bempp:HOST:INFO: GMRES Iteration 106 with residual 0.010487324925174311
# bempp:HOST:INFO: GMRES Iteration 107 with residual 0.010260277346578084
# bempp:HOST:INFO: GMRES Iteration 108 with residual 0.009964634193799704
# bempp:HOST:INFO: GMRES Iteration 109 with residual 0.009711994781763348
# bempp:HOST:INFO: GMRES Iteration 110 with residual 0.009500403910604046
# bempp:HOST:INFO: GMRES Iteration 111 with residual 0.00927019110989592
# bempp:HOST:INFO: GMRES Iteration 112 with residual 0.009077063634088625
# bempp:HOST:INFO: GMRES Iteration 113 with residual 0.008834896722426596
# bempp:HOST:INFO: GMRES Iteration 114 with residual 0.008596279850826977
# bempp:HOST:INFO: GMRES Iteration 115 with residual 0.008389098707223845
# bempp:HOST:INFO: GMRES Iteration 116 with residual 0.008154625449435233
# bempp:HOST:INFO: GMRES Iteration 117 with residual 0.007954054190114426
# bempp:HOST:INFO: GMRES Iteration 118 with residual 0.007741921066172382
# bempp:HOST:INFO: GMRES Iteration 119 with residual 0.007576220887275419
# bempp:HOST:INFO: GMRES Iteration 120 with residual 0.007384482535999227
# bempp:HOST:INFO: GMRES Iteration 121 with residual 0.007196664085531316
# bempp:HOST:INFO: GMRES Iteration 122 with residual 0.007038854409797043
# bempp:HOST:INFO: GMRES Iteration 123 with residual 0.006861851954984715
# bempp:HOST:INFO: GMRES Iteration 124 with residual 0.006711861545189977
# bempp:HOST:INFO: GMRES Iteration 125 with residual 0.006517256350615946
# bempp:HOST:INFO: GMRES Iteration 126 with residual 0.006399796474958189
# bempp:HOST:INFO: GMRES Iteration 127 with residual 0.006238703909051234
# bempp:HOST:INFO: GMRES Iteration 128 with residual 0.006109127749609077
# bempp:HOST:INFO: GMRES Iteration 129 with residual 0.0059863068502732765
# bempp:HOST:INFO: GMRES Iteration 130 with residual 0.005836983935453189
# bempp:HOST:INFO: GMRES Iteration 131 with residual 0.005720652756125064
# bempp:HOST:INFO: GMRES Iteration 132 with residual 0.005575130403721749
# bempp:HOST:INFO: GMRES Iteration 133 with residual 0.005437938037137667
# bempp:HOST:INFO: GMRES Iteration 134 with residual 0.005313034182814278
# bempp:HOST:INFO: GMRES Iteration 135 with residual 0.005175588074479051
# bempp:HOST:INFO: GMRES Iteration 136 with residual 0.005048212610313313
# bempp:HOST:INFO: GMRES Iteration 137 with residual 0.004936260879784583
# bempp:HOST:INFO: GMRES Iteration 138 with residual 0.004807893245510877
# bempp:HOST:INFO: GMRES Iteration 139 with residual 0.004706691303782868
# bempp:HOST:INFO: GMRES Iteration 140 with residual 0.004615527966665301
# bempp:HOST:INFO: GMRES Iteration 141 with residual 0.004491925956275583
# bempp:HOST:INFO: GMRES Iteration 142 with residual 0.004386264120463023
# bempp:HOST:INFO: GMRES Iteration 143 with residual 0.00427732797109474
# bempp:HOST:INFO: GMRES Iteration 144 with residual 0.0041938593880999015
# bempp:HOST:INFO: GMRES Iteration 145 with residual 0.004081270242949106
# bempp:HOST:INFO: GMRES Iteration 146 with residual 0.00397860873938252
# bempp:HOST:INFO: GMRES Iteration 147 with residual 0.0038758251327390336
# bempp:HOST:INFO: GMRES Iteration 148 with residual 0.0037937443466706444
# bempp:HOST:INFO: GMRES Iteration 149 with residual 0.003696336312417367
# bempp:HOST:INFO: GMRES Iteration 150 with residual 0.0036208264329255888
# bempp:HOST:INFO: GMRES Iteration 151 with residual 0.003542936891553261
# bempp:HOST:INFO: GMRES Iteration 152 with residual 0.0034601794687156248
# bempp:HOST:INFO: GMRES Iteration 153 with residual 0.0033731357277841036
# bempp:HOST:INFO: GMRES Iteration 154 with residual 0.0033065884721644517
# bempp:HOST:INFO: GMRES Iteration 155 with residual 0.0032390591094793373
# bempp:HOST:INFO: GMRES Iteration 156 with residual 0.003157440082187551
# bempp:HOST:INFO: GMRES Iteration 157 with residual 0.0030781319987067493
# bempp:HOST:INFO: GMRES Iteration 158 with residual 0.0030255502555320934
# bempp:HOST:INFO: GMRES Iteration 159 with residual 0.0029470460704678837
# bempp:HOST:INFO: GMRES Iteration 160 with residual 0.002884893541639137
# bempp:HOST:INFO: GMRES Iteration 161 with residual 0.0028236642102756416
# bempp:HOST:INFO: GMRES Iteration 162 with residual 0.0027627621851737936
# bempp:HOST:INFO: GMRES Iteration 163 with residual 0.0027077152649511425
# bempp:HOST:INFO: GMRES Iteration 164 with residual 0.0026343715802521965
# bempp:HOST:INFO: GMRES Iteration 165 with residual 0.002579393526301771
# bempp:HOST:INFO: GMRES Iteration 166 with residual 0.002523015959002884
# bempp:HOST:INFO: GMRES Iteration 167 with residual 0.0024675259238896583
# bempp:HOST:INFO: GMRES Iteration 168 with residual 0.0024214538211080926
# bempp:HOST:INFO: GMRES Iteration 169 with residual 0.0023623591731982505
# bempp:HOST:INFO: GMRES Iteration 170 with residual 0.002322014790896727
# bempp:HOST:INFO: GMRES Iteration 171 with residual 0.0022651697293352598
# bempp:HOST:INFO: GMRES Iteration 172 with residual 0.002210738526525977
# bempp:HOST:INFO: GMRES Iteration 173 with residual 0.0021722654587483423
# bempp:HOST:INFO: GMRES Iteration 174 with residual 0.0021230382278511367
# bempp:HOST:INFO: GMRES Iteration 175 with residual 0.0020808161168325563
# bempp:HOST:INFO: GMRES Iteration 176 with residual 0.002031679264370627
# bempp:HOST:INFO: GMRES Iteration 177 with residual 0.002001717159800082
# bempp:HOST:INFO: GMRES Iteration 178 with residual 0.0019561755771302087
# bempp:HOST:INFO: GMRES Iteration 179 with residual 0.0019220540246168332
# bempp:HOST:INFO: GMRES Iteration 180 with residual 0.001875676257582761
# bempp:HOST:INFO: GMRES Iteration 181 with residual 0.0018406308332266023
# bempp:HOST:INFO: GMRES Iteration 182 with residual 0.0018012336904562917
# bempp:HOST:INFO: GMRES Iteration 183 with residual 0.0017667709641934178
# bempp:HOST:INFO: GMRES Iteration 184 with residual 0.0017325882724355316
# bempp:HOST:INFO: GMRES Iteration 185 with residual 0.0016921689364416536
# bempp:HOST:INFO: GMRES Iteration 186 with residual 0.0016637807240272578
# bempp:HOST:INFO: GMRES Iteration 187 with residual 0.0016355023198371182
# bempp:HOST:INFO: GMRES Iteration 188 with residual 0.0016020534600159617
# bempp:HOST:INFO: GMRES Iteration 189 with residual 0.0015670359329688903
# bempp:HOST:INFO: GMRES Iteration 190 with residual 0.0015322846640541446
# bempp:HOST:INFO: GMRES Iteration 191 with residual 0.0014985805221159605
# bempp:HOST:INFO: GMRES Iteration 192 with residual 0.0014678441023150586
# bempp:HOST:INFO: GMRES Iteration 193 with residual 0.0014421681115699997
# bempp:HOST:INFO: GMRES Iteration 194 with residual 0.0014076697133485003
# bempp:HOST:INFO: GMRES Iteration 195 with residual 0.0013816944713026347
# bempp:HOST:INFO: GMRES Iteration 196 with residual 0.0013524332193247828
# bempp:HOST:INFO: GMRES Iteration 197 with residual 0.0013230777520646538
# bempp:HOST:INFO: GMRES Iteration 198 with residual 0.001297408583920667
# bempp:HOST:INFO: GMRES Iteration 199 with residual 0.0012696089624161639
# bempp:HOST:INFO: GMRES Iteration 200 with residual 0.0012476069860275012
# bempp:HOST:INFO: GMRES Iteration 201 with residual 0.001222119363179723
# bempp:HOST:INFO: GMRES Iteration 202 with residual 0.001200812586213229
# bempp:HOST:INFO: GMRES Iteration 203 with residual 0.0011746701366715441
# bempp:HOST:INFO: GMRES Iteration 204 with residual 0.0011479637366496316
# bempp:HOST:INFO: GMRES Iteration 205 with residual 0.001128048207961525
# bempp:HOST:INFO: GMRES Iteration 206 with residual 0.0011031061838170833
# bempp:HOST:INFO: GMRES Iteration 207 with residual 0.0010828035774988942
# bempp:HOST:INFO: GMRES Iteration 208 with residual 0.0010620844365928626
# bempp:HOST:INFO: GMRES Iteration 209 with residual 0.0010437411520288881
# bempp:HOST:INFO: GMRES Iteration 210 with residual 0.0010204721559863353
# bempp:HOST:INFO: GMRES Iteration 211 with residual 0.0010060754862984613
# bempp:HOST:INFO: GMRES Iteration 212 with residual 0.0009875776759408785
# bempp:HOST:INFO: GMRES Iteration 213 with residual 0.0009685440141820858
# bempp:HOST:INFO: GMRES Iteration 214 with residual 0.0009522203169955602
# bempp:HOST:INFO: GMRES Iteration 215 with residual 0.0009363715409271068
# bempp:HOST:INFO: GMRES Iteration 216 with residual 0.0009190498743922576
# bempp:HOST:INFO: GMRES Iteration 217 with residual 0.0009064880363969586
# bempp:HOST:INFO: GMRES Iteration 218 with residual 0.0008882793964610978
# bempp:HOST:INFO: GMRES Iteration 219 with residual 0.0008751998282076225
# bempp:HOST:INFO: GMRES Iteration 220 with residual 0.0008579521229419356
# bempp:HOST:INFO: GMRES Iteration 221 with residual 0.0008449425567049979
# bempp:HOST:INFO: GMRES Iteration 222 with residual 0.0008284898585991158
# bempp:HOST:INFO: GMRES Iteration 223 with residual 0.0008140711209948753
# bempp:HOST:INFO: GMRES Iteration 224 with residual 0.0008017386083476323
# bempp:HOST:INFO: GMRES Iteration 225 with residual 0.0007854256455895337
# bempp:HOST:INFO: GMRES Iteration 226 with residual 0.0007731108336922816
# bempp:HOST:INFO: GMRES Iteration 227 with residual 0.0007589626169194421
# bempp:HOST:INFO: GMRES Iteration 228 with residual 0.0007468897511208778
# bempp:HOST:INFO: GMRES Iteration 229 with residual 0.0007345804343205459
# bempp:HOST:INFO: GMRES Iteration 230 with residual 0.0007218376870164069
# bempp:HOST:INFO: GMRES Iteration 231 with residual 0.0007083903386829055
# bempp:HOST:INFO: GMRES Iteration 232 with residual 0.0006974748852624215
# bempp:HOST:INFO: GMRES Iteration 233 with residual 0.0006867244119860399
# bempp:HOST:INFO: GMRES Iteration 234 with residual 0.0006720991449082224
# bempp:HOST:INFO: GMRES Iteration 235 with residual 0.0006628365255306087
# bempp:HOST:INFO: GMRES Iteration 236 with residual 0.0006510901793889305
# bempp:HOST:INFO: GMRES Iteration 237 with residual 0.0006375289379625827
# bempp:HOST:INFO: GMRES Iteration 238 with residual 0.0006272230917490292
# bempp:HOST:INFO: GMRES Iteration 239 with residual 0.0006126138038591517
# bempp:HOST:INFO: GMRES Iteration 240 with residual 0.0006033079905803263
# bempp:HOST:INFO: GMRES Iteration 241 with residual 0.000590176024755028
# bempp:HOST:INFO: GMRES Iteration 242 with residual 0.0005808346778489002
# bempp:HOST:INFO: GMRES Iteration 243 with residual 0.0005706617328258213
# bempp:HOST:INFO: GMRES Iteration 244 with residual 0.0005587310064955415
# bempp:HOST:INFO: GMRES Iteration 245 with residual 0.0005500046469248189
# bempp:HOST:INFO: GMRES Iteration 246 with residual 0.0005388488155928836
# bempp:HOST:INFO: GMRES Iteration 247 with residual 0.0005258118902878328
# bempp:HOST:INFO: GMRES Iteration 248 with residual 0.000517898305402378
# bempp:HOST:INFO: GMRES Iteration 249 with residual 0.0005065207478791525
# bempp:HOST:INFO: GMRES Iteration 250 with residual 0.000497000548920976
# bempp:HOST:INFO: GMRES Iteration 251 with residual 0.0004877727281547236
# bempp:HOST:INFO: GMRES Iteration 252 with residual 0.0004786846136520247
# bempp:HOST:INFO: GMRES Iteration 253 with residual 0.0004691692812082015
# bempp:HOST:INFO: GMRES Iteration 254 with residual 0.0004603276575487097
# bempp:HOST:INFO: GMRES Iteration 255 with residual 0.0004512840174356315
# bempp:HOST:INFO: GMRES Iteration 256 with residual 0.0004420201920470805
# bempp:HOST:INFO: GMRES Iteration 257 with residual 0.00043495798000157363
# bempp:HOST:INFO: GMRES Iteration 258 with residual 0.00042668522870237334
# bempp:HOST:INFO: GMRES Iteration 259 with residual 0.00041916535352253746
# bempp:HOST:INFO: GMRES Iteration 260 with residual 0.00041150452418326963
# bempp:HOST:INFO: GMRES Iteration 261 with residual 0.0004042327192746305
# bempp:HOST:INFO: GMRES Iteration 262 with residual 0.00039675350804587703
# bempp:HOST:INFO: GMRES Iteration 263 with residual 0.0003889905728112595
# bempp:HOST:INFO: GMRES Iteration 264 with residual 0.0003827181527291371
# bempp:HOST:INFO: GMRES Iteration 265 with residual 0.00037552178286677284
# bempp:HOST:INFO: GMRES Iteration 266 with residual 0.0003680334017844256
# bempp:HOST:INFO: GMRES Iteration 267 with residual 0.00036182459274157637
# bempp:HOST:INFO: GMRES Iteration 268 with residual 0.00035503616663605655
# bempp:HOST:INFO: GMRES Iteration 269 with residual 0.00034778878718990004
# bempp:HOST:INFO: GMRES Iteration 270 with residual 0.00034151079563701065
# bempp:HOST:INFO: GMRES Iteration 271 with residual 0.0003354930732357008
# bempp:HOST:INFO: GMRES Iteration 272 with residual 0.0003288522871361068
# bempp:HOST:INFO: GMRES Iteration 273 with residual 0.00032254595916832184
# bempp:HOST:INFO: GMRES Iteration 274 with residual 0.0003173136742942354
# bempp:HOST:INFO: GMRES Iteration 275 with residual 0.0003100835450023729
# bempp:HOST:INFO: GMRES Iteration 276 with residual 0.00030388343156031376
# bempp:HOST:INFO: GMRES Iteration 277 with residual 0.0002979413783654206
# bempp:HOST:INFO: GMRES Iteration 278 with residual 0.0002921478938943042
# bempp:HOST:INFO: GMRES Iteration 279 with residual 0.00028667212768976465
# bempp:HOST:INFO: GMRES Iteration 280 with residual 0.0002806754752815206
# bempp:HOST:INFO: GMRES Iteration 281 with residual 0.00027527960444012655
# bempp:HOST:INFO: GMRES Iteration 282 with residual 0.0002692732722588871
# bempp:HOST:INFO: GMRES Iteration 283 with residual 0.00026485012503233026
# bempp:HOST:INFO: GMRES Iteration 284 with residual 0.00025896010336193454
# bempp:HOST:INFO: GMRES Iteration 285 with residual 0.00025307542060105297
# bempp:HOST:INFO: GMRES Iteration 286 with residual 0.00024859705086078344
# bempp:HOST:INFO: GMRES Iteration 287 with residual 0.00024369399153544602
# bempp:HOST:INFO: GMRES Iteration 288 with residual 0.00023797462891968297
# bempp:HOST:INFO: GMRES Iteration 289 with residual 0.0002333788807453003
# bempp:HOST:INFO: GMRES Iteration 290 with residual 0.00022943951474793436
# bempp:HOST:INFO: GMRES Iteration 291 with residual 0.0002234380763863162
# bempp:HOST:INFO: GMRES Iteration 292 with residual 0.00021935747450220263
# bempp:HOST:INFO: GMRES Iteration 293 with residual 0.000214533015767842
# bempp:HOST:INFO: GMRES Iteration 294 with residual 0.00020992222897569883
# bempp:HOST:INFO: GMRES Iteration 295 with residual 0.00020594565797676698
# bempp:HOST:INFO: GMRES Iteration 296 with residual 0.00020058051158478677
# bempp:HOST:INFO: GMRES Iteration 297 with residual 0.0001964429067610918
# bempp:HOST:INFO: GMRES Iteration 298 with residual 0.00019202476279945484
# bempp:HOST:INFO: GMRES Iteration 299 with residual 0.00018773483727492024
# bempp:HOST:INFO: GMRES Iteration 300 with residual 0.0001832920143521964
# bempp:HOST:INFO: GMRES Iteration 301 with residual 0.00017921070100736645
# bempp:HOST:INFO: GMRES Iteration 302 with residual 0.00017631181884214894
# bempp:HOST:INFO: GMRES Iteration 303 with residual 0.00017102418611067413
# bempp:HOST:INFO: GMRES Iteration 304 with residual 0.00016809487774403474
# bempp:HOST:INFO: GMRES Iteration 305 with residual 0.00016476224777723646
# bempp:HOST:INFO: GMRES Iteration 306 with residual 0.00016032674829881971
# bempp:HOST:INFO: GMRES Iteration 307 with residual 0.00015777664566464904
# bempp:HOST:INFO: GMRES Iteration 308 with residual 0.00015390286118998372
# bempp:HOST:INFO: GMRES Iteration 309 with residual 0.00015031579978011132
# bempp:HOST:INFO: GMRES Iteration 310 with residual 0.000147318883358707
# bempp:HOST:INFO: GMRES Iteration 311 with residual 0.00014400109390638654
# bempp:HOST:INFO: GMRES Iteration 312 with residual 0.00014082075026693365
# bempp:HOST:INFO: GMRES Iteration 313 with residual 0.00013766038229112498
# bempp:HOST:INFO: GMRES Iteration 314 with residual 0.00013503348176668867
# bempp:HOST:INFO: GMRES Iteration 315 with residual 0.00013191561487286538
# bempp:HOST:INFO: GMRES Iteration 316 with residual 0.00012890128051899202
# bempp:HOST:INFO: GMRES Iteration 317 with residual 0.00012645882643070615
# bempp:HOST:INFO: GMRES Iteration 318 with residual 0.00012289456315087404
# bempp:HOST:INFO: GMRES Iteration 319 with residual 0.00012063346738291982
# bempp:HOST:INFO: GMRES Iteration 320 with residual 0.00011807684841814398
# bempp:HOST:INFO: GMRES Iteration 321 with residual 0.00011534386181618186
# bempp:HOST:INFO: GMRES Iteration 322 with residual 0.00011304283259195497
# bempp:HOST:INFO: GMRES Iteration 323 with residual 0.0001103736015647805
# bempp:HOST:INFO: GMRES Iteration 324 with residual 0.0001084630503175564
# bempp:HOST:INFO: GMRES Iteration 325 with residual 0.0001059243626796834
# bempp:HOST:INFO: GMRES Iteration 326 with residual 0.00010367895965641527
# bempp:HOST:INFO: GMRES Iteration 327 with residual 0.00010204533987068824
# bempp:HOST:INFO: GMRES Iteration 328 with residual 9.961427398985737e-05
# bempp:HOST:INFO: GMRES Iteration 329 with residual 9.773624924899068e-05
# bempp:HOST:INFO: GMRES Iteration 330 with residual 9.561129833060072e-05
# bempp:HOST:INFO: GMRES Iteration 331 with residual 9.357923892863134e-05
# bempp:HOST:INFO: GMRES Iteration 332 with residual 9.193376846378679e-05
# bempp:HOST:INFO: GMRES Iteration 333 with residual 8.976411987144413e-05
# bempp:HOST:INFO: GMRES Iteration 334 with residual 8.806913716465682e-05
# bempp:HOST:INFO: GMRES Iteration 335 with residual 8.653125510122849e-05
# bempp:HOST:INFO: GMRES Iteration 336 with residual 8.459324881577153e-05
# bempp:HOST:INFO: GMRES Iteration 337 with residual 8.301914402101576e-05
# bempp:HOST:INFO: GMRES Iteration 338 with residual 8.129778166520568e-05
# bempp:HOST:INFO: GMRES Iteration 339 with residual 7.964832356004836e-05
# bempp:HOST:INFO: GMRES Iteration 340 with residual 7.798156197882299e-05
# bempp:HOST:INFO: GMRES Iteration 341 with residual 7.652723907778393e-05
# bempp:HOST:INFO: GMRES Iteration 342 with residual 7.491143461622261e-05
# bempp:HOST:INFO: GMRES Iteration 343 with residual 7.334108960218799e-05
# bempp:HOST:INFO: GMRES Iteration 344 with residual 7.199375046433025e-05
# bempp:HOST:INFO: GMRES Iteration 345 with residual 7.011656101866278e-05
# bempp:HOST:INFO: GMRES Iteration 346 with residual 6.869573462567582e-05
# bempp:HOST:INFO: GMRES Iteration 347 with residual 6.736194109861368e-05
# bempp:HOST:INFO: GMRES Iteration 348 with residual 6.573065112767438e-05
# bempp:HOST:INFO: GMRES Iteration 349 with residual 6.457529919516005e-05
# bempp:HOST:INFO: GMRES Iteration 350 with residual 6.303018841097478e-05
# bempp:HOST:INFO: GMRES Iteration 351 with residual 6.171702513428184e-05
# bempp:HOST:INFO: GMRES Iteration 352 with residual 6.057350473266779e-05
# bempp:HOST:INFO: GMRES Iteration 353 with residual 5.893286270875929e-05
# bempp:HOST:INFO: GMRES Iteration 354 with residual 5.775162266424922e-05
# bempp:HOST:INFO: GMRES Iteration 355 with residual 5.661443044675929e-05
# bempp:HOST:INFO: GMRES Iteration 356 with residual 5.524107386298428e-05
# bempp:HOST:INFO: GMRES Iteration 357 with residual 5.4209366893592814e-05
# bempp:HOST:INFO: GMRES Iteration 358 with residual 5.297312006208897e-05
# bempp:HOST:INFO: GMRES Iteration 359 with residual 5.197659182843992e-05
# bempp:HOST:INFO: GMRES Iteration 360 with residual 5.093291731701662e-05
# bempp:HOST:INFO: GMRES Iteration 361 with residual 4.9787667746156704e-05
# bempp:HOST:INFO: GMRES Iteration 362 with residual 4.8768768320061827e-05
# bempp:HOST:INFO: GMRES Iteration 363 with residual 4.7677531443976084e-05
# bempp:HOST:INFO: GMRES Iteration 364 with residual 4.6780562337416455e-05
# bempp:HOST:INFO: GMRES Iteration 365 with residual 4.554643148994028e-05
# bempp:HOST:INFO: GMRES Iteration 366 with residual 4.464623786873079e-05
# bempp:HOST:INFO: GMRES Iteration 367 with residual 4.36941261246488e-05
# bempp:HOST:INFO: GMRES Iteration 368 with residual 4.274371919296259e-05
# bempp:HOST:INFO: GMRES Iteration 369 with residual 4.187314808610083e-05
# bempp:HOST:INFO: GMRES Iteration 370 with residual 4.089953712558048e-05
# bempp:HOST:INFO: GMRES Iteration 371 with residual 4.005603649897225e-05
# bempp:HOST:INFO: GMRES Iteration 372 with residual 3.9082370798765474e-05
# bempp:HOST:INFO: GMRES Iteration 373 with residual 3.830962153685888e-05
# bempp:HOST:INFO: GMRES Iteration 374 with residual 3.737778500807086e-05
# bempp:HOST:INFO: GMRES Iteration 375 with residual 3.6552808780031315e-05
# bempp:HOST:INFO: GMRES Iteration 376 with residual 3.5791934182469164e-05
# bempp:HOST:INFO: GMRES Iteration 377 with residual 3.493474705246539e-05
# bempp:HOST:INFO: GMRES Iteration 378 with residual 3.4226035369096426e-05
# bempp:HOST:INFO: GMRES Iteration 379 with residual 3.3471262998871974e-05
# bempp:HOST:INFO: GMRES Iteration 380 with residual 3.2741923135131254e-05
# bempp:HOST:INFO: GMRES Iteration 381 with residual 3.198174758661895e-05
# bempp:HOST:INFO: GMRES Iteration 382 with residual 3.13527853232845e-05
# bempp:HOST:INFO: GMRES Iteration 383 with residual 3.062381484578499e-05
# bempp:HOST:INFO: GMRES Iteration 384 with residual 2.9942050719100454e-05
# bempp:HOST:INFO: GMRES Iteration 385 with residual 2.9418862778150425e-05
# bempp:HOST:INFO: GMRES Iteration 386 with residual 2.8626811992960016e-05
# bempp:HOST:INFO: GMRES Iteration 387 with residual 2.8058134711872355e-05
# bempp:HOST:INFO: GMRES Iteration 388 with residual 2.7397872679278222e-05
# bempp:HOST:INFO: GMRES Iteration 389 with residual 2.6820089013689863e-05
# bempp:HOST:INFO: GMRES Iteration 390 with residual 2.6345992663331748e-05
# bempp:HOST:INFO: GMRES Iteration 391 with residual 2.5726984675472105e-05
# bempp:HOST:INFO: GMRES Iteration 392 with residual 2.5155163070773745e-05
# bempp:HOST:INFO: GMRES Iteration 393 with residual 2.4650433231782293e-05
# bempp:HOST:INFO: GMRES Iteration 394 with residual 2.4093316252762366e-05
# bempp:HOST:INFO: GMRES Iteration 395 with residual 2.3567161158845766e-05
# bempp:HOST:INFO: GMRES Iteration 396 with residual 2.299729196095505e-05
# bempp:HOST:INFO: GMRES Iteration 397 with residual 2.2579066824586492e-05
# bempp:HOST:INFO: GMRES Iteration 398 with residual 2.2072551456531984e-05
# bempp:HOST:INFO: GMRES Iteration 399 with residual 2.164427484791167e-05
# bempp:HOST:INFO: GMRES Iteration 400 with residual 2.1159294463916096e-05
# bempp:HOST:INFO: GMRES Iteration 401 with residual 2.0736228790770244e-05
# bempp:HOST:INFO: GMRES Iteration 402 with residual 2.0284879989028692e-05
# bempp:HOST:INFO: GMRES Iteration 403 with residual 1.9871251549078615e-05
# bempp:HOST:INFO: GMRES Iteration 404 with residual 1.9451457242974105e-05
# bempp:HOST:INFO: GMRES Iteration 405 with residual 1.9028348878072795e-05
# bempp:HOST:INFO: GMRES Iteration 406 with residual 1.8598772585814446e-05
# bempp:HOST:INFO: GMRES Iteration 407 with residual 1.8190512139424165e-05
# bempp:HOST:INFO: GMRES Iteration 408 with residual 1.777988185729289e-05
# bempp:HOST:INFO: GMRES Iteration 409 with residual 1.7424619057695037e-05
# bempp:HOST:INFO: GMRES Iteration 410 with residual 1.7019487847395138e-05
# bempp:HOST:INFO: GMRES Iteration 411 with residual 1.6664837709452745e-05
# bempp:HOST:INFO: GMRES Iteration 412 with residual 1.628946129490009e-05
# bempp:HOST:INFO: GMRES Iteration 413 with residual 1.590411303875119e-05
# bempp:HOST:INFO: GMRES Iteration 414 with residual 1.555028724334504e-05
# bempp:HOST:INFO: GMRES Iteration 415 with residual 1.5206555331490028e-05
# bempp:HOST:INFO: GMRES Iteration 416 with residual 1.4853198184660435e-05
# bempp:HOST:INFO: GMRES Iteration 417 with residual 1.4476867526273164e-05
# bempp:HOST:INFO: GMRES Iteration 418 with residual 1.4167386216301684e-05
# bempp:HOST:INFO: GMRES Iteration 419 with residual 1.383950073915902e-05
# bempp:HOST:INFO: GMRES Iteration 420 with residual 1.3528429568936798e-05
# bempp:HOST:INFO: GMRES Iteration 421 with residual 1.3217944881218751e-05
# bempp:HOST:INFO: GMRES Iteration 422 with residual 1.2883232347862577e-05
# bempp:HOST:INFO: GMRES Iteration 423 with residual 1.2596789856101452e-05
# bempp:HOST:INFO: GMRES Iteration 424 with residual 1.2337092681264987e-05
# bempp:HOST:INFO: GMRES Iteration 425 with residual 1.2024089906822991e-05
# bempp:HOST:INFO: GMRES Iteration 426 with residual 1.1725344013768517e-05
# bempp:HOST:INFO: GMRES Iteration 427 with residual 1.146025649071975e-05
# bempp:HOST:INFO: GMRES Iteration 428 with residual 1.1161491923832307e-05
# bempp:HOST:INFO: GMRES Iteration 429 with residual 1.0924118987103023e-05
# bempp:HOST:INFO: GMRES Iteration 430 with residual 1.0703940118981131e-05
# bempp:HOST:INFO: GMRES Iteration 431 with residual 1.0417352631862101e-05
# bempp:HOST:INFO: GMRES Iteration 432 with residual 1.0210247804669532e-05
# bempp:HOST:INFO: GMRES Iteration 433 with residual 9.975544510368582e-06
# bempp:HOST:INFO: GMRES finished in 433 iterations and took 1.45E+01 sec.
# /usr/local/lib/python3.10/dist-packages/pyopencl/cache.py:495: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   _create_built_program_from_source_cached(
# /usr/local/lib/python3.10/dist-packages/pyopencl/cache.py:499: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   prg.build(options_bytes, devices)
# 0.01085549801322834 REL
# 0.010859336549515982 REL_GMRES

# %%
angles = config['angles']

fig, ax  = plt.subplots(1,1, figsize=(6,6))
plt.rcParams['figure.figsize'] = (15, 4) # Increase the figure size in the notebook

A22 = far_field[2,:]
uh = 10 * np.log10(4 * np.pi * np.abs(A22[:1801]))
uh_gmres = 10 * np.log10(4 * np.pi * np.abs(A22_gmres[:1801]))
u =  10 * np.log10(4 * np.pi * np.abs(s1 / (-1j * k_ext) ))
# -1j * kExt is to make agree with eqn 3.21 p70 tBohren and Huffman

ax.plot(angles[:1801], uh, '-r', label='BEM')
ax.plot(angles[:1801], uh_gmres, '--g', label='BEM_GMRES')
ax.plot(angles[:1801], u, 'b', label='MIE', linestyle=(0, (5, 5)))

ax.set_xlabel(r"$\theta$ (rad)", fontsize=15)
ax.set_ylabel(r"$\mathrm{RCS}_z(\theta)$", fontsize=15)

ymin, ymax = uh.min() - 1, uh.max() + 1
ax.legend(prop={'size': 14})
ax.grid()
plt.xlim(-0.1, np.pi + 0.1)
#plt.ylim(ymin, ymax)
#plt.savefig("plots/RCSSphere.pdf")
plt.show()
