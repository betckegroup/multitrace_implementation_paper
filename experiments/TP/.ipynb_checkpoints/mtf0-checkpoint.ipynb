# %%
#Je reviens à quelque chose de beaucoup plus simple. On va prouver que l'on obtient le bon FF pour STF classique. 
#Travaillons en mode dense, facile.
# This first version is for the classical STF. 
# Now, try to get to the domain-based STF...

import bempp.api 
import numpy as np
import mtf
from mtf.preconditioning.osrc import osrc_MtE
from mtf.utils.iterative import gmres

from bempp.api.operators.boundary.sparse import identity

from bempp.api.assembly.blocked_operator import BlockedOperator
from mtf.assembly.operators import GeneralizedBlockedOperator
from bempp.api import ZeroBoundaryOperator

from mtf.utils import bhmie
from mtf.config import config
from mtf.functions import define_bempp_functions
from matplotlib import pyplot as plt
from decimal import Decimal

bempp.api.enable_console_logging()
M = 2

mtf.config.set_case("B")

tangential_trace, neumann_trace = define_bempp_functions(config)

k0, k1 = config["k_ext"], config["k_int"]
lambda_par, freq = config["lambda"], config["frequency"]

polarization = config["polarization"]
direction = config["direction"]

eps_rel = config["eps_rel"]
mu_rel = config["mu_rel"]
mu0 = config["mu_ext"]
mu1 = mu_rel * mu0

eta_rel = np.sqrt(mu_rel / eps_rel)

print("The exterior wavenumber is: {0}".format(k0))
print("The interior wavenumber is: {0}".format(k1))

print("----")
print("The exterior wavelenght is: {0}".format(lambda_par))
print("The exterior frequency is: {:.2E}".format(Decimal(freq)))

# To do: Go to the multi-domain STF...
segments = [[10], [10]]
swapped_normals = [[10], []]

k_int, k_ext = config["k_int"], config["k_ext"]

n = k_int / k_ext
refIndex = n
numAngles = 901
s1, s2, qext, qsca, qback, gsca = bhmie(k_ext, k_int / k_ext, numAngles)
angles = config['angles']

k_list = [k0]
eta_rel_list = [1]
mu_list = [mu0]

for index in range(M-1):
  k_list.append(k1)
  mu_list.append(mu1)
  eta_rel_list.append(eta_rel)


precision = 10

h = 2 * np.pi/(precision*k0)
grid = bempp.api.shapes.sphere(h=h)

print(h, ': h')
print(precision, ': precision')
print(grid.number_of_edges * 2, ': N')


dA = [bempp.api.function_space(grid, "RWG", 0, segments=seg, swapped_normals=normals,
                                      include_boundary_dofs=True)
              for seg, normals in zip(segments, swapped_normals)]

p1dA = [bempp.api.function_space(grid, "DP", 1, segments=seg, swapped_normals=normals,
                                      include_boundary_dofs=True)
              for seg, normals in zip(segments, swapped_normals)]

rA = [bempp.api.function_space(grid, "RWG", 0, segments=seg, swapped_normals=normals,
                                      include_boundary_dofs=True)
              for seg, normals in zip(segments, swapped_normals)]
tA = [bempp.api.function_space(grid, "SNC", 0, segments=seg, swapped_normals=normals,
                                      include_boundary_dofs=True)
              for seg, normals in zip(segments, swapped_normals)]

multitrace_ops = []
osrc_ops = []
# > Assemble all diagonal operators
for index in range(M):
  k = k_list[index]
  mu = mu_list[index]
  eta = eta_rel_list[index]
  efie = bempp.api.operators.boundary.maxwell.electric_field(dA[index], rA[index], tA[index], k)
  mfie = bempp.api.operators.boundary.maxwell.magnetic_field(dA[index], rA[index], tA[index], k)
  osrc = osrc_MtE(dA[index], rA[index], tA[index], p1dA[index], k)
  zero = (1+1j) * bempp.api.ZeroBoundaryOperator(dA[index], rA[index], tA[index])
  multitrace_ops.append(GeneralizedBlockedOperator([[mfie, eta * efie],[- 1/eta * efie, mfie]]))
  osrc_ops.append(GeneralizedBlockedOperator([[zero, eta * osrc],[- 1/eta * osrc, zero]]))
    
# Define the final operator
block_system = [M * [None] for _ in range(M)]

for i in range(M):
  for j in range(M):
    if i == j:
      block_system[i][j] = 2 * multitrace_ops[i]
    else:
      all = segments[i] + segments[j]
      non_disjoint = np.unique(all).shape[0] != len(all)
      
      if non_disjoint:
        ident = identity(dA[j], rA[i], tA[i])
        op = BlockedOperator(2, 2)
        #op[0, 0] = -ident
        op[0, 0] = ident
        op[1, 1] = ident
        op.weak_form()
        #op[1, 1] = ident
        block_system[i][j] = op
      else:
        op = BlockedOperator(2, 2)
        zero = ZeroBoundaryOperator(dA[j], rA[i], tA[i])
        op[0, 0] = zero
        op[1, 1] = zero
        block_system[i][j] = op

# Define the final operator
block_osrc = [M * [None] for _ in range(M)]

for i in range(M):
  for j in range(M):
    if i == j:
      block_osrc[i][j] = 2 * osrc_ops[i]
    else:
      all = segments[i] + segments[j]
      non_disjoint = np.unique(all).shape[0] != len(all)
      
      if non_disjoint:
        ident = identity(dA[j], rA[i], tA[i])
        op = BlockedOperator(2, 2)
        #op[0, 0] = -ident
        op[0, 0] = ident
        op[1, 1] = ident
        op.weak_form()
        #op[1, 1] = ident
        block_osrc[i][j] = op
      else:
        op = BlockedOperator(2, 2)
        zero = ZeroBoundaryOperator(dA[j], rA[i], tA[i])
        op[0, 0] = zero
        op[1, 1] = zero
        block_osrc[i][j] = op

for i in range(M):
  for j in range(M):
    if i == j:
      block_osrc[i][j] = 2 * osrc_ops[i]
    else:
      op = BlockedOperator(2, 2)
      zero = ZeroBoundaryOperator(dA[j], rA[i], tA[i])
      op[0, 0] = zero
      op[1, 1] = zero
      block_osrc[i][j] = op

lhs_op = GeneralizedBlockedOperator(block_system)
op_wf = lhs_op.weak_form()

P_op = GeneralizedBlockedOperator(block_osrc)
P_wf = P_op.weak_form()

rhs = [2 * bempp.api.GridFunction(rA[0], dual_space = tA[0], fun=tangential_trace),
      2 * bempp.api.GridFunction(rA[0], dual_space = tA[0], fun=neumann_trace)]

for i in range(1, M):
    zero_func = [bempp.api.GridFunction.from_zeros(dA[i]),bempp.api.GridFunction.from_zeros(dA[i])]
    rhs = rhs + zero_func


b = bempp.api.assembly.blocked_operator.projections_from_grid_functions_list(rhs, lhs_op.dual_to_range_spaces)
N = b.shape[0]
A = bempp.api.as_matrix(op_wf)
x = np.linalg.solve(A, b)

x_gmres, conv_gmres, res_gmres = gmres(P_wf * op_wf, P_wf * b, return_residuals=True, restart = 1000)
#x_gmres, conv_gmres, res_gmres = gmres(op_wf, b, return_residuals=True, restart = 1000, maxiter=1000)

sol = bempp.api.assembly.blocked_operator.grid_function_list_from_coefficients(x.ravel(), lhs_op.domain_spaces)
sol_gmres = bempp.api.assembly.blocked_operator.grid_function_list_from_coefficients(x_gmres.ravel(), lhs_op.domain_spaces)

far_field_points = config['far_field_points']
electric_far = bempp.api.operators.far_field.maxwell.electric_field(sol[1].space, far_field_points, k0)
magnetic_far = bempp.api.operators.far_field.maxwell.magnetic_field(sol[0].space, far_field_points, k0)    

far_field =  electric_far * sol[1] + magnetic_far * sol[0]

far_field_gmres =  electric_far * sol_gmres[1] + magnetic_far * sol_gmres[0]

A22 = far_field[2,:]
A22_gmres = far_field_gmres[2,:]
uh = 10 * np.log10(4 * np.pi * np.abs(A22[:1801]))
uh_gmres = 10 * np.log10(4 * np.pi * np.abs(A22_gmres[:1801]))
u =  10 * np.log10(4 * np.pi * np.abs(s1 / (-1j * k_ext) ))
rel_error = np.linalg.norm(uh - u) / np.linalg.norm(u)
rel_error_gmres = np.linalg.norm(uh_gmres - u) / np.linalg.norm(u)

print(rel_error, 'REL')
print(rel_error_gmres, 'REL_GMRES')
# Out:
# The exterior wavenumber is: 5.0
# The interior wavenumber is: 6.892024376045111
# ----
# The exterior wavelenght is: 1.2566370614359172
# The exterior frequency is: 2.39E+8
# bempp:HOST:INFO: Created grid with id 3144fadc-dc75-4533-9937-8d297f4dbc15. Elements: 2122. Edges: 3183. Vertices: 1063
# bempp:HOST:WARNING: Setting include_boundary_dofs has no effect on this space type.
# bempp:HOST:WARNING: Setting include_boundary_dofs has no effect on this space type.
# 0.12566370614359174 : h
# 10 : precision
# 6366 : N
# /usr/local/lib/python3.10/dist-packages/bempp/api/assembly/discrete_boundary_operator.py:639: SparseEfficiencyWarning: splu converted its input to CSC format
#   solver = solver_interface(actual_mat)
# /usr/local/lib/python3.10/dist-packages/bempp/api/assembly/discrete_boundary_operator.py:639: SparseEfficiencyWarning: splu converted its input to CSC format
#   solver = solver_interface(actual_mat)
# bempp:HOST:INFO: OpenCL CPU Device set to: pthread-AMD EPYC 7302 16-Core Processor
# 66 warnings generated.
# /usr/local/lib/python3.10/dist-packages/pyopencl/cache.py:417: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   prg.build(options_bytes, [devices[i] for i in to_be_built_indices])
# 66 warnings generated.
# /usr/local/lib/python3.10/dist-packages/pyopencl/cache.py:495: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   _create_built_program_from_source_cached(
# /usr/local/lib/python3.10/dist-packages/pyopencl/cache.py:499: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   prg.build(options_bytes, devices)
# 66 warnings generated.
# 66 warnings generated.
# bempp:HOST:INFO: Starting GMRES iteration
# bempp:HOST:INFO: GMRES Iteration 1 with residual 0.6747594896153257
# bempp:HOST:INFO: GMRES Iteration 2 with residual 0.5662082751657432
# bempp:HOST:INFO: GMRES Iteration 3 with residual 0.4501075450197883
# bempp:HOST:INFO: GMRES Iteration 4 with residual 0.40194495789135776
# bempp:HOST:INFO: GMRES Iteration 5 with residual 0.33262025682893603
# bempp:HOST:INFO: GMRES Iteration 6 with residual 0.27226308660277365
# bempp:HOST:INFO: GMRES Iteration 7 with residual 0.23404246110807853
# bempp:HOST:INFO: GMRES Iteration 8 with residual 0.18874072262846767
# bempp:HOST:INFO: GMRES Iteration 9 with residual 0.17211433974151877
# bempp:HOST:INFO: GMRES Iteration 10 with residual 0.15271376209312756
# bempp:HOST:INFO: GMRES Iteration 11 with residual 0.12608757132017745
# bempp:HOST:INFO: GMRES Iteration 12 with residual 0.11209128324442863
# bempp:HOST:INFO: GMRES Iteration 13 with residual 0.09650873565458452
# bempp:HOST:INFO: GMRES Iteration 14 with residual 0.08753821266773783
# bempp:HOST:INFO: GMRES Iteration 15 with residual 0.0737209781696597
# bempp:HOST:INFO: GMRES Iteration 16 with residual 0.06735149534282556
# bempp:HOST:INFO: GMRES Iteration 17 with residual 0.05528231977728285
# bempp:HOST:INFO: GMRES Iteration 18 with residual 0.04519224603651169
# bempp:HOST:INFO: GMRES Iteration 19 with residual 0.04036706722346275
# bempp:HOST:INFO: GMRES Iteration 20 with residual 0.03227447352335668
# bempp:HOST:INFO: GMRES Iteration 21 with residual 0.029448467523407115
# bempp:HOST:INFO: GMRES Iteration 22 with residual 0.0240441648793328
# bempp:HOST:INFO: GMRES Iteration 23 with residual 0.019620652227721323
# bempp:HOST:INFO: GMRES Iteration 24 with residual 0.01720813791164787
# bempp:HOST:INFO: GMRES Iteration 25 with residual 0.015463208315540428
# bempp:HOST:INFO: GMRES Iteration 26 with residual 0.014235003650694336
# bempp:HOST:INFO: GMRES Iteration 27 with residual 0.012177622664676858
# bempp:HOST:INFO: GMRES Iteration 28 with residual 0.009990489482341238
# bempp:HOST:INFO: GMRES Iteration 29 with residual 0.00921400450562794
# bempp:HOST:INFO: GMRES Iteration 30 with residual 0.008488581144715903
# bempp:HOST:INFO: GMRES Iteration 31 with residual 0.007754295300303661
# bempp:HOST:INFO: GMRES Iteration 32 with residual 0.006946369492979181
# bempp:HOST:INFO: GMRES Iteration 33 with residual 0.006175936395103211
# bempp:HOST:INFO: GMRES Iteration 34 with residual 0.005290969506767348
# bempp:HOST:INFO: GMRES Iteration 35 with residual 0.0046456866724394865
# bempp:HOST:INFO: GMRES Iteration 36 with residual 0.00419610826940284
# bempp:HOST:INFO: GMRES Iteration 37 with residual 0.0038921423391596517
# bempp:HOST:INFO: GMRES Iteration 38 with residual 0.0036381798034060757
# bempp:HOST:INFO: GMRES Iteration 39 with residual 0.0033335984659658056
# bempp:HOST:INFO: GMRES Iteration 40 with residual 0.003000985255727104
# bempp:HOST:INFO: GMRES Iteration 41 with residual 0.0027228647075319976
# bempp:HOST:INFO: GMRES Iteration 42 with residual 0.002483903782104398
# bempp:HOST:INFO: GMRES Iteration 43 with residual 0.00230477434231056
# bempp:HOST:INFO: GMRES Iteration 44 with residual 0.002147517040385694
# bempp:HOST:INFO: GMRES Iteration 45 with residual 0.0019907931378637623
# bempp:HOST:INFO: GMRES Iteration 46 with residual 0.001870623255804321
# bempp:HOST:INFO: GMRES Iteration 47 with residual 0.0017406496949004912
# bempp:HOST:INFO: GMRES Iteration 48 with residual 0.001609597945965769
# bempp:HOST:INFO: GMRES Iteration 49 with residual 0.0015001806882292996
# bempp:HOST:INFO: GMRES Iteration 50 with residual 0.0013847152084558558
# bempp:HOST:INFO: GMRES Iteration 51 with residual 0.0012746389401493464
# bempp:HOST:INFO: GMRES Iteration 52 with residual 0.0011908964811075209
# bempp:HOST:INFO: GMRES Iteration 53 with residual 0.001109472418598155
# bempp:HOST:INFO: GMRES Iteration 54 with residual 0.0010490725319420482
# bempp:HOST:INFO: GMRES Iteration 55 with residual 0.0009842509331558034
# bempp:HOST:INFO: GMRES Iteration 56 with residual 0.0009420535078969186
# bempp:HOST:INFO: GMRES Iteration 57 with residual 0.0008791931462794371
# bempp:HOST:INFO: GMRES Iteration 58 with residual 0.0008359694546300014
# bempp:HOST:INFO: GMRES Iteration 59 with residual 0.000790447811824487
# bempp:HOST:INFO: GMRES Iteration 60 with residual 0.0007535556077216352
# bempp:HOST:INFO: GMRES Iteration 61 with residual 0.000715600812655486
# bempp:HOST:INFO: GMRES Iteration 62 with residual 0.000680889253840411
# bempp:HOST:INFO: GMRES Iteration 63 with residual 0.0006479425297025243
# bempp:HOST:INFO: GMRES Iteration 64 with residual 0.0006202246811045738
# bempp:HOST:INFO: GMRES Iteration 65 with residual 0.0005818882028598867
# bempp:HOST:INFO: GMRES Iteration 66 with residual 0.0005601836427165809
# bempp:HOST:INFO: GMRES Iteration 67 with residual 0.0005315898938878796
# bempp:HOST:INFO: GMRES Iteration 68 with residual 0.0005105602843055386
# bempp:HOST:INFO: GMRES Iteration 69 with residual 0.0004905534272823637
# bempp:HOST:INFO: GMRES Iteration 70 with residual 0.0004697890494011943
# bempp:HOST:INFO: GMRES Iteration 71 with residual 0.0004514856200131897
# bempp:HOST:INFO: GMRES Iteration 72 with residual 0.00043220060125809224
# bempp:HOST:INFO: GMRES Iteration 73 with residual 0.00041275872481376006
# bempp:HOST:INFO: GMRES Iteration 74 with residual 0.00039408667052880103
# bempp:HOST:INFO: GMRES Iteration 75 with residual 0.0003737740817460947
# bempp:HOST:INFO: GMRES Iteration 76 with residual 0.000359323714001317
# bempp:HOST:INFO: GMRES Iteration 77 with residual 0.00033706363510793534
# bempp:HOST:INFO: GMRES Iteration 78 with residual 0.0003227921967627517
# bempp:HOST:INFO: GMRES Iteration 79 with residual 0.0003060162089729254
# bempp:HOST:INFO: GMRES Iteration 80 with residual 0.00029250662332053727
# bempp:HOST:INFO: GMRES Iteration 81 with residual 0.00027939909681102485
# bempp:HOST:INFO: GMRES Iteration 82 with residual 0.0002676811280462823
# bempp:HOST:INFO: GMRES Iteration 83 with residual 0.00025669724786533396
# bempp:HOST:INFO: GMRES Iteration 84 with residual 0.00024344327186344133
# bempp:HOST:INFO: GMRES Iteration 85 with residual 0.00023133727249566665
# bempp:HOST:INFO: GMRES Iteration 86 with residual 0.00022241384696274663
# bempp:HOST:INFO: GMRES Iteration 87 with residual 0.00021327576518257753
# bempp:HOST:INFO: GMRES Iteration 88 with residual 0.00020548439751489044
# bempp:HOST:INFO: GMRES Iteration 89 with residual 0.00019756013148026176
# bempp:HOST:INFO: GMRES Iteration 90 with residual 0.00019047677206190662
# bempp:HOST:INFO: GMRES Iteration 91 with residual 0.00018366751786507403
# bempp:HOST:INFO: GMRES Iteration 92 with residual 0.00017745243307730463
# bempp:HOST:INFO: GMRES Iteration 93 with residual 0.00017156188286543373
# bempp:HOST:INFO: GMRES Iteration 94 with residual 0.0001661675892477773
# bempp:HOST:INFO: GMRES Iteration 95 with residual 0.00015925854208230565
# bempp:HOST:INFO: GMRES Iteration 96 with residual 0.00015171943827546873
# bempp:HOST:INFO: GMRES Iteration 97 with residual 0.00014387029370991255
# bempp:HOST:INFO: GMRES Iteration 98 with residual 0.00013770087854690475
# bempp:HOST:INFO: GMRES Iteration 99 with residual 0.0001306879201981774
# bempp:HOST:INFO: GMRES Iteration 100 with residual 0.0001244541407399833
# bempp:HOST:INFO: GMRES Iteration 101 with residual 0.00011826653907702738
# bempp:HOST:INFO: GMRES Iteration 102 with residual 0.0001126311729555558
# bempp:HOST:INFO: GMRES Iteration 103 with residual 0.00010697214674695925
# bempp:HOST:INFO: GMRES Iteration 104 with residual 0.00010244306672645522
# bempp:HOST:INFO: GMRES Iteration 105 with residual 9.84529517596806e-05
# bempp:HOST:INFO: GMRES Iteration 106 with residual 9.460761865221278e-05
# bempp:HOST:INFO: GMRES Iteration 107 with residual 9.0942681390333e-05
# bempp:HOST:INFO: GMRES Iteration 108 with residual 8.760188349764615e-05
# bempp:HOST:INFO: GMRES Iteration 109 with residual 8.434482515881303e-05
# bempp:HOST:INFO: GMRES Iteration 110 with residual 8.124748937717473e-05
# bempp:HOST:INFO: GMRES Iteration 111 with residual 7.819392436513348e-05
# bempp:HOST:INFO: GMRES Iteration 112 with residual 7.500633365472538e-05
# bempp:HOST:INFO: GMRES Iteration 113 with residual 7.205320397927524e-05
# bempp:HOST:INFO: GMRES Iteration 114 with residual 6.959400847370765e-05
# bempp:HOST:INFO: GMRES Iteration 115 with residual 6.722464005510331e-05
# bempp:HOST:INFO: GMRES Iteration 116 with residual 6.520465854821934e-05
# bempp:HOST:INFO: GMRES Iteration 117 with residual 6.294877459376974e-05
# bempp:HOST:INFO: GMRES Iteration 118 with residual 6.08806101814625e-05
# bempp:HOST:INFO: GMRES Iteration 119 with residual 5.8817593645530265e-05
# bempp:HOST:INFO: GMRES Iteration 120 with residual 5.6925494739930035e-05
# bempp:HOST:INFO: GMRES Iteration 121 with residual 5.537410101282973e-05
# bempp:HOST:INFO: GMRES Iteration 122 with residual 5.378333015722515e-05
# bempp:HOST:INFO: GMRES Iteration 123 with residual 5.2275858987200593e-05
# bempp:HOST:INFO: GMRES Iteration 124 with residual 5.081247071223201e-05
# bempp:HOST:INFO: GMRES Iteration 125 with residual 4.930399419918537e-05
# bempp:HOST:INFO: GMRES Iteration 126 with residual 4.773496961298531e-05
# bempp:HOST:INFO: GMRES Iteration 127 with residual 4.622507260714677e-05
# bempp:HOST:INFO: GMRES Iteration 128 with residual 4.4633389565673615e-05
# bempp:HOST:INFO: GMRES Iteration 129 with residual 4.3073796415683347e-05
# bempp:HOST:INFO: GMRES Iteration 130 with residual 4.1566874906676636e-05
# bempp:HOST:INFO: GMRES Iteration 131 with residual 4.013101374741107e-05
# bempp:HOST:INFO: GMRES Iteration 132 with residual 3.860145162848087e-05
# bempp:HOST:INFO: GMRES Iteration 133 with residual 3.7497700552331007e-05
# bempp:HOST:INFO: GMRES Iteration 134 with residual 3.614299359365904e-05
# bempp:HOST:INFO: GMRES Iteration 135 with residual 3.5093502136269574e-05
# bempp:HOST:INFO: GMRES Iteration 136 with residual 3.399188446590787e-05
# bempp:HOST:INFO: GMRES Iteration 137 with residual 3.271934640221045e-05
# bempp:HOST:INFO: GMRES Iteration 138 with residual 3.1679118764477907e-05
# bempp:HOST:INFO: GMRES Iteration 139 with residual 3.0757925801917764e-05
# bempp:HOST:INFO: GMRES Iteration 140 with residual 2.99287084798527e-05
# bempp:HOST:INFO: GMRES Iteration 141 with residual 2.9141935025246985e-05
# bempp:HOST:INFO: GMRES Iteration 142 with residual 2.8254825884253195e-05
# bempp:HOST:INFO: GMRES Iteration 143 with residual 2.7447556812535803e-05
# bempp:HOST:INFO: GMRES Iteration 144 with residual 2.6717464379740423e-05
# bempp:HOST:INFO: GMRES Iteration 145 with residual 2.5961816661099362e-05
# bempp:HOST:INFO: GMRES Iteration 146 with residual 2.531883777545732e-05
# bempp:HOST:INFO: GMRES Iteration 147 with residual 2.4486448208163945e-05
# bempp:HOST:INFO: GMRES Iteration 148 with residual 2.36335799016722e-05
# bempp:HOST:INFO: GMRES Iteration 149 with residual 2.276522408826076e-05
# bempp:HOST:INFO: GMRES Iteration 150 with residual 2.1928600488551808e-05
# bempp:HOST:INFO: GMRES Iteration 151 with residual 2.108194300483276e-05
# bempp:HOST:INFO: GMRES Iteration 152 with residual 2.026633761546064e-05
# bempp:HOST:INFO: GMRES Iteration 153 with residual 1.9346083308961262e-05
# bempp:HOST:INFO: GMRES Iteration 154 with residual 1.858856397198689e-05
# bempp:HOST:INFO: GMRES Iteration 155 with residual 1.780851698979551e-05
# bempp:HOST:INFO: GMRES Iteration 156 with residual 1.7026712238435052e-05
# bempp:HOST:INFO: GMRES Iteration 157 with residual 1.64104573072087e-05
# bempp:HOST:INFO: GMRES Iteration 158 with residual 1.5842455955184346e-05
# bempp:HOST:INFO: GMRES Iteration 159 with residual 1.5275482204414726e-05
# bempp:HOST:INFO: GMRES Iteration 160 with residual 1.4663298525736986e-05
# bempp:HOST:INFO: GMRES Iteration 161 with residual 1.4072024833924644e-05
# bempp:HOST:INFO: GMRES Iteration 162 with residual 1.360971475230686e-05
# bempp:HOST:INFO: GMRES Iteration 163 with residual 1.3119032665989126e-05
# bempp:HOST:INFO: GMRES Iteration 164 with residual 1.2627848387023415e-05
# bempp:HOST:INFO: GMRES Iteration 165 with residual 1.2216076259398347e-05
# bempp:HOST:INFO: GMRES Iteration 166 with residual 1.1792775749054618e-05
# bempp:HOST:INFO: GMRES Iteration 167 with residual 1.1375545255070118e-05
# bempp:HOST:INFO: GMRES Iteration 168 with residual 1.0934196302438266e-05
# bempp:HOST:INFO: GMRES Iteration 169 with residual 1.0499982893774475e-05
# bempp:HOST:INFO: GMRES Iteration 170 with residual 1.0145496042858153e-05
# bempp:HOST:INFO: GMRES Iteration 171 with residual 9.799381790944273e-06
# bempp:HOST:INFO: GMRES finished in 171 iterations and took 2.08E+01 sec.
# /usr/local/lib/python3.10/dist-packages/pyopencl/cache.py:495: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   _create_built_program_from_source_cached(
# /usr/local/lib/python3.10/dist-packages/pyopencl/cache.py:499: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   prg.build(options_bytes, devices)
# 66 warnings generated.
# /usr/local/lib/python3.10/dist-packages/pyopencl/cache.py:417: CompilerWarning: Non-empty compiler output encountered. Set the environment variable PYOPENCL_COMPILER_OUTPUT=1 to see more.
#   prg.build(options_bytes, [devices[i] for i in to_be_built_indices])
# 66 warnings generated.
# 0.0038960562658201434 REL
# 0.003900535919658451 REL_GMRES

# %%
angles = config['angles']

fig, ax  = plt.subplots(1,1, figsize=(6,6))
plt.rcParams['figure.figsize'] = (15, 4) # Increase the figure size in the notebook

A22 = far_field[2,:]
uh = 10 * np.log10(4 * np.pi * np.abs(A22[:1801]))
uh_gmres = 10 * np.log10(4 * np.pi * np.abs(A22_gmres[:1801]))
u =  10 * np.log10(4 * np.pi * np.abs(s1 / (-1j * k_ext) ))
# -1j * kExt is to make agree with eqn 3.21 p70 tBohren and Huffman

ax.plot(angles[:1801], uh, '-r', label='BEM')
ax.plot(angles[:1801], uh_gmres, '--g', label='BEM_GMRES')
ax.plot(angles[:1801], u, 'b', label='MIE', linestyle=(0, (5, 5)))

ax.set_xlabel(r"$\theta$ (rad)", fontsize=15)
ax.set_ylabel(r"$\mathrm{RCS}_z(\theta)$", fontsize=15)

ymin, ymax = uh.min() - 1, uh.max() + 1
ax.legend(prop={'size': 14})
ax.grid()
plt.xlim(-0.1, np.pi + 0.1)
#plt.ylim(ymin, ymax)
#plt.savefig("plots/RCSSphere.pdf")
plt.show()
